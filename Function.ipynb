# %% [markdown]
# # FUNCTION

# %%
def add():
    print("Enter two numbers")
    a = int(input())
    b = int(input())
    c = a + b
    print("sum is", c)
add()
# Out:
# Enter two numbers
#  34
#  56
# sum is 90

# %% [markdown]
# # Takes Nothing, Returns Nothing

# %%
def add1():
    print("Enter two  Numbers")
    a , b = int(input()),int(input())
    c = a + b
    print("sum is" , c)

# %%
add1()
# Out:
# Enter two  Numbers
#  22
#  55
# sum is 77

# %% [markdown]
# # Take something Return Nothing

# %%
def add2(a, b):
    c = a + b
    print("sum is", c)
def main():
    x = 10
    y = 20
    add2(x,y)
main()
# Out:
# sum is 30

# %% [markdown]
# # Takes Nothing , Return Something

# %%
def add3():
    print("Enter two Numbers")
    a, b = int(input()), int(input())
    c = a + b
    return c
def main():
    s = add3()
    print("Result is", s)
main()
# Out:
# Enter two Numbers
#  66
#  65
# Result is 131

# %% [markdown]
# # Take Something , Return Something

# %%
def add4(a, b):
    x, y = 10, 20
    s = add4(x,y)
    print("Sum of", x, "and", y, "is",s)
main()
# Out:
# Enter two Numbers
#  234
#  3221
# Result is 3455

# %% [markdown]
# # DEFAULT ARGUMENTS

# %%
def add(a, b):
    return(a + b)
def main():
    print("sum of 2 and 3 is ",add(2,3))
main()
# Out:
# sum of 2 and 3 is  5

# %% [markdown]
# # Formal arguments and Actual Arguments will take equal variable & EQual value

# %%
def add(a, b):
    return(a + b)
def main():
    print("sum of 2 and 3 is ",add(2,3))
main()
# Out:
# sum of 2 and 3 is  5

# %% [markdown]
# # IF u put LESS variable And u put extra value it will throw an error

# %%
def add(a, b):
    return(a + b)
def main():
    print("sum of 2 and 3 is ",add(2,3))
main()
# Out:
# sum of 2 and 3 is  5

# %% [markdown]
#  # IF I Made Function Overloading, Here is no overloading concept in python. It may be in C, Java laungage

# %%
def add(a, b, c):
    return a + b + c
def add (a, b,c):
    return a + b +c
def main():
    print("sum of 10, 20 and 30 is ", add(10, 20, 30))
    print("sum of 10,20 and 30",add(10, 20, 30))
main()
# Out:
# sum of 10, 20 and 30 is  60
# sum of 10,20 and 30 60

# %%
 n = 1275 
 n = n//10
print(n)
# Out:
# 127

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
